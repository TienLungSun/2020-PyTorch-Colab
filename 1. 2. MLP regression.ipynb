# %% [markdown]
# # Recognize device

# %%
import torch

# %%
if(torch.cuda.is_available()):
    device = torch.device("cuda")
    print(device, torch.cuda.get_device_name(0))
else:
    device= torch.device("cpu")
    print(device)
# Out:
# cpu

# %% [markdown]
# # Read data file

# %% [markdown]
# 用 excel 建一個 data file:
#
# N= 100, x1 = RAND(), x2=RANDBETWEEN(-100, 100)/100, x3=RANDBETWEEN(-100, 100)/100
#
# y = 2*x1^2 + 5*x2^3 + 6*x3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ea82e4a4-2032-410b-8340-c1fff8e73554" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea82e4a4-2032-410b-8340-c1fff8e73554">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data-y=f(x1, x2, x3).xlsx to data-y=f(x1, x2, x3).xlsx

# %%
fnameLst = list(uploaded.keys())
fname = fnameLst[0]
print(fname)
# Out:
# data-y=f(x1, x2, x3).xlsx

# %%
import pandas as pd
df=pd.read_excel(fname)

# %%
df.head(5)
# Out:
#          x1    x2    x3         y
# 0  0.627431 -0.04 -0.73 -3.592980
# 1  0.054560 -0.39 -0.88 -5.570641
# 2  0.212407  0.26 -0.77 -4.441887
# 3  0.858315 -0.32  0.77  5.929569
# 4  0.758817  0.21 -0.26 -0.362090

# %%
df.columns
# Out:
# Index(['x1', 'x2', 'x3', 'y'], dtype='object')

# %% [markdown]
# # Convert training data to tensor

# %%
dfX = df[['x1', 'x2', 'x3']]
print(dfX.shape)
# Out:
# (100, 3)

# %%
tensorX = torch.FloatTensor(dfX.values).to(device)
print(tensorX.shape)
# Out:
# torch.Size([100, 3])

# %%
dfY = df['y']
print(dfY.shape)
# Out:
# (100,)

# %%
tensorY = torch.FloatTensor(dfY.values).to(device)
tensorY = tensorY.view(tensorY.shape[0], 1)
print(tensorY.shape)
# Out:
# torch.Size([100, 1])

# %% [markdown]
# # Build NN

# %%
import torch.nn as nn

# %%
MyNet = nn.Sequential(
    nn.Linear(3, 30),
    nn.ReLU(),
    nn.Linear(30, 15),
    nn.ReLU(),
    nn.Linear(15, 1),
)
MyNet.to(device)
print(MyNet)
# Out:
# Sequential(
#   (0): Linear(in_features=3, out_features=30, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=30, out_features=15, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=15, out_features=1, bias=True)
# )

# %%
loss_func = torch.nn.MSELoss()

# %%
optimizer = torch.optim.Adam(MyNet.parameters(), lr=0.05)

# %% [markdown]
# # 練習 one training

# %%
tensorY1 = MyNet(tensorX)
loss = loss_func(tensorY1, tensorY)
print(float(loss))
optimizer.zero_grad()
loss.backward()
optimizer.step()
# Out:
# 14.467607498168945

# %% [markdown]
# # Training Loop

# %%
lossLst = []
for epoch in range(1, 30):
    tensorY1 = MyNet(tensorX)
    loss = loss_func(tensorY1, tensorY)
    loss1 = float(loss)
    print("%.2f" % (loss1), end = ", ")
    lossLst.append(loss1)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# 12.65, 10.29, 7.59, 5.81, 5.30, 3.57, 2.72, 3.10, 2.96, 2.44, 2.48, 2.13, 1.38, 1.05, 1.13, 1.20, 1.11, 0.98, 0.97, 1.04, 1.04, 0.95, 0.91, 0.92, 0.89, 0.79, 0.69, 0.66, 0.69,

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(lossLst)
plt.show()

# %% [markdown]
# # 測試訓練結果

# %%
import random

# %%
lstX = []
lstY = []
lstY1 = []
for i in range(100):
  x1=random.uniform(0, 1)
  x2=random.randint(-100, 100)/100
  x3=random.randint(-100, 100)/100
  y = 2*x1*x1 + 5*x2*x2*x2 + 6*x3
  lstY.append(y)
  
  lstX = [[x1, x2, x3]]
  tensorX = torch.FloatTensor(lstX).to(device)
  tensorY1 = MyNet(tensorX)
  lstY1.append(float(tensorY1))

# %%
plt.figure(figsize=(18, 9))
plt.plot(lstY)
plt.plot(lstY1)
plt.show()
